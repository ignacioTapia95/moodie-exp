# %% [markdown]
# source: https://huggingface.co/docs/transformers/model_doc/clip

# %%
# !pip install matplotlib
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#   Using cached matplotlib-3.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.55.3-cp312-cp312-macosx_10_13_universal2.whl.metadata (165 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.2 kB)
# ...
# Using cached matplotlib-3.10.0-cp312-cp312-macosx_11_0_arm64.whl (8.0 MB)
# Using cached contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl (255 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...

# %%
import numpy as np
from PIL import Image
import requests
import matplotlib.pyplot as plt

from transformers import CLIPProcessor, CLIPModel

# %%
model = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")

# %%
shot_types = [
    "Extreme Long Shot",  # Plano general extremo
    "Long Shot",          # Plano general
    "Full Shot",          # Plano entero
    "Medium Long Shot",   # Plano americano
    "Medium Shot",        # Plano medio
    "Medium Close-Up",    # Plano medio corto
    "Close-Up",           # Primer plano
    "Extreme Close-Up",   # Primerisimo primer plano
    "Insert Shot",
]

# %%
shot_types = [
    "Gran Plano General",  # Plano general extremo
    "Plano General",          # Plano general
    "Plano Americano",   # Plano americano
    "Plano Medio",        # Plano medio
    "Primer Plano",           # Primer plano
    "Primerísimo Primer Plano",   # Primerisimo primer plano
    "Inserto",
]

# %%
path = "../../data/processed/image/tt4652838/tt4652838-Scene-828-02.jpg"
image = Image.open(path)

inputs = processor(text=shot_types, images=image, return_tensors="pt", padding=True)
outputs = model(**inputs)
logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)

predicted_index = np.argmax(probs.cpu().detach().numpy())
predicted_label = shot_types[predicted_index]
predicted_prob = probs[0, predicted_index].item()

plt.imshow(image)
plt.axis("off")
plt.title(f"Predicción: {predicted_label}\nProbabilidad: {predicted_prob:.2f}")
plt.show()

# %% [markdown]
# ### Angulo de Camara

# %%
camera_angles = [
    "High Angle",           # Ángulo picado (cámara por encima del sujeto)
    "Low Angle",            # Ángulo contrapicado (cámara por debajo del sujeto)
    "Eye Level",            # Ángulo a nivel de los ojos (neutral y natural)
    "Extreme High Angle",   # Ángulo picado extremo (cámara muy por encima del sujeto)
    "Extreme Low Angle",    # Ángulo contrapicado extremo (cámara muy por debajo del sujeto)
    "Bird's Eye View",      # Ángulo cenital (vista desde directamente arriba)
    "Worm's Eye View"       # Ángulo nadir o de gusano (vista desde directamente abajo)
]

# %%
path = "../../data/processed/image/tt4652838/tt4652838-Scene-483-02.jpg"
image = Image.open(path)

inputs = processor(text=camera_angles, images=image, return_tensors="pt", padding=True)
outputs = model(**inputs)
logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)

predicted_index = np.argmax(probs.cpu().detach().numpy())
predicted_label = camera_angles[predicted_index]
predicted_prob = probs[0, predicted_index].item()

plt.imshow(image)
plt.axis("off")
plt.title(f"Predicción: {predicted_label}\nProbabilidad: {predicted_prob:.2f}")
plt.show()

# %% [markdown]
# ### Momento de dia

# %%
time_of_day = [
    "morning",
    "midday",
    "afternoon",
    "evening",
    "night",
]

# %%
path = "../../data/processed/image/tt4652838/tt4652838-Scene-435-02.jpg"
image = Image.open(path)

inputs = processor(text=time_of_day, images=image, return_tensors="pt", padding=True)
outputs = model(**inputs)
logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)

predicted_index = np.argmax(probs.cpu().detach().numpy())
predicted_label = time_of_day[predicted_index]
predicted_prob = probs[0, predicted_index].item()

plt.imshow(image)
plt.axis("off")
plt.title(f"Predicción: {predicted_label}\nProbabilidad: {predicted_prob:.2f}")
plt.show()

# %%
path = "../../data/processed/image/tt4652838/tt4652838-Scene-600-02.jpg"
image = Image.open(path)

inputs = processor(text=time_of_day, images=image, return_tensors="pt", padding=True)
outputs = model(**inputs)
logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)

predicted_index = np.argmax(probs.cpu().detach().numpy())
predicted_label = time_of_day[predicted_index]
predicted_prob = probs[0, predicted_index].item()

plt.imshow(image)
plt.axis("off")
plt.title(f"Predicción: {predicted_label}\nProbabilidad: {predicted_prob:.2f}")
plt.show()

# %% [markdown]
# ### Light Types
#
# TODO: obtener tipo de iluminacion a traves del histograma

# %%
lighting_types = [
    "Natural Lighting",        # Iluminación natural (luz del sol o fuentes naturales)
    "Artificial Lighting",     # Iluminación artificial (luces controladas como focos y LEDs)
    "High Key Lighting",       # Iluminación de alta clave (brillante y uniforme)
    "Low Key Lighting",        # Iluminación de baja clave (sombras profundas y contrastes altos)
    "Backlighting",            # Contraluz (luz detrás del sujeto, creando siluetas)
    "Soft Lighting",           # Iluminación suave (luz difusa, sombras suaves)
    "Hard Lighting",           # Iluminación dura (luz directa, sombras marcadas)
    "Side Lighting",           # Iluminación lateral (luz desde un lado, resaltando texturas)
    "Overhead Lighting",       # Iluminación cenital (luz desde arriba, dramatismo)
    "Colored Lighting"         # Iluminación de colores (rojo, azul, verde, etc., para transmitir emociones)
]

# %%
path = "../../data/processed/image/tt4652838/tt4652838-Scene-355-02.jpg"
image = Image.open(path)

inputs = processor(text=lighting_types, images=image, return_tensors="pt", padding=True)
outputs = model(**inputs)
logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1)

predicted_index = np.argmax(probs.cpu().detach().numpy())
predicted_label = lighting_types[predicted_index]
predicted_prob = probs[0, predicted_index].item()

plt.imshow(image)
plt.axis("off")
plt.title(f"Predicción: {predicted_label}\nProbabilidad: {predicted_prob:.2f}")
plt.show()
